# %%
import pandas as pd
import matplotlib as plt
import sklearn as skl
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import numpy as np
import nltk
import sys

# %%
df = pd.read_csv('..\WHUPL\Output\BMW.csv')
df
# Out:
#       auction_code  car_year     color make            model   subseries  \
# 0              MAA      2013      BLUE  BMW        740LI XDR   740LI XDR
# 1              MAA      2017    SILVER  BMW  430I XDRIVE CPE  430I XDRIV
# 2              MAA      2017      BLUE  BMW    X3 35I XDRIVE   XDRIVE35I
# 3              MAA      2016    SILVER  BMW    X5 35I XDRIVE   35IX MSPT
# 4              MAA      2007      BLUE  BMW          X5 4.8L        4.8I
# ...            ...       ...       ...  ...              ...         ...
# 79693          MAA      2015  SPCEGREY  BMW      535I XDRIVE   535IX LUX
# 79694          MAA      2009      BLUE  BMW        X5 3.0 SI         30I
# 79695          MAA      2017      GREY  BMW  430I XDRIVE CNV   430IX SPT
# 79696          MAA      2016      GREY  BMW      528I XDRIVE  528IX MSPT
# 79697          MAA      2016      BLUE  BMW      320I XDRIVE  320I XDRIV
#
#        body engine transmission  mileage  condition_grade  times_run   seller  \
# ...

# %%
df = df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
df
# Out:
#       auction_code  car_year     color make            model  body  \
# 0              MAA      2013      BLUE  BMW        740LI XDR  4DSN
# 1              MAA      2017    SILVER  BMW  430I XDRIVE CPE  2DCP
# 2              MAA      2017      BLUE  BMW    X3 35I XDRIVE   SUV
# 3              MAA      2016    SILVER  BMW    X5 35I XDRIVE   SUV
# 4              MAA      2007      BLUE  BMW          X5 4.8L  4CUV
# ...            ...       ...       ...  ...              ...   ...
# 79693          MAA      2015  SPCEGREY  BMW      535I XDRIVE  4DSN
# 79694          MAA      2009      BLUE  BMW        X5 3.0 SI  4CUV
# 79695          MAA      2017      GREY  BMW  430I XDRIVE CNV  2DCV
# 79696          MAA      2016      GREY  BMW      528I XDRIVE  4DSN
# 79697          MAA      2016      BLUE  BMW      320I XDRIVE  4DSN
#
#       transmission  mileage  condition_grade  times_run  sale_price  \
# 0                A    47357               39          1       20900
# ...

# %%
models = df.describe(include = 'all').loc['unique', :]
m = []
for i in df['model'].unique():
    m.append(i)
    
m.sort()
print(m)
# Out:
# ['128I', '128I CNV', '128I CP', '128I CPE', '128I CV', '135I', '135I CNV', '135I CPE', '135I CV', '135IS CNV', '135IS CPE', '135M', '228I', '228I CNV', '228I CV', '228I XDRIVE', '228IX', '228IX CNV', '230I', '230IX', '3 SERIES', '3 SERIES GRA', '3 SERIES M3', '318', '318TI', '320I', '320I XDRIVE', '320I XDRIVE 0', '323CI', '323CIC', '323I', '323IC', '325', '325CI', '325CIC', '325I', '325IT', '325XI', '325XIT', '328', '328CI', '328D', '328D XDR WGN', '328D XDRIVE', '328I', '328I CNV', '328I CP', '328I CPE', '328I CV', '328I LUX', '328I MSPT', '328I SA', '328I SPT', '328I WGN', '328I XDR', '328I XDR CPE', '328I XDR WGN', '328I XDRIVE', '328I XDRIVE GT', '328I XDRIVE0', '328IC', '328IX MSPT', '328XI', '330', '330CI', '330CIC', '330E', '330E LUX', '330I', '330I XDR WGN', '330I XDRIVE', '330I XDRIVE GT', '330XI', '335CI', '335D', '335I', '335I CNV', '335I CONV', '335I CP', '335I CPE', '335I CV', '335I SA', '335I SPT PKG', '335I XDR', '335I XDR CPE', '335I XDR MSPORT', '335I XDRIVE', '335I
# ...

# %%
_128i = '128I'
_135i = '135I'
_228i = '228I'
_230i = '230I'
_3_series = '3 Series'
_318 = '318'
_320i = '320I'
_323i = '323I'
_325i = '325I'
_328i = '328I'
_330i = '330I'
_335i = '335I'
_340i = '340I'
_4_series = '4 Series'
_428i = '428I'
_430i = '430I'
_435i = '435I'
_440i = '440I'
_5_series = '5 Series'
_525i = '525I'
_528i = '528I'
_530i = '530I'
_535i = '535I'
_545i = '545I'
_550i = '550I'
_6_series = '6 Series'
_640i = '640I'
_645i = '645I'
_650i = '650I'
_7_series = '7 Series'
_740i = '740I'
_745i = '745I'
_750i = '750I'
_760i = '760I'
_840i = '840I'
ACTHY3 = 'ACTHY3'
ACTHY5 = 'ACTHY5'
ALP_B6 = 'B6'
ALP_B7 = 'B7'
I3 = 'I3'
I8 = 'I8'
K1200 = 'K1200'
M2 = 'M2'
M235I = 'M235I'
M240I = 'M240I'
M3 = 'M3'
M4 = 'M4'
M5 = 'M5'
M550I = 'M550I'
M6 = 'M6'
X1 = 'X1'
X3 = 'X3'
X4 = 'X4'
X5 = 'X5'
X6 = 'X6'
Z3 = 'Z3'
Z4 = 'Z4'

model = _128i

# %%
model_list = [_128i, _135i, _228i, _230i, _3_series, _318, _320i,
             _323i, _325i, _328i, _330i, _335i, _340i, _4_series,
             _428i, _430i, _435i, _440i, _5_series, _525i, _528i,
             _530i, _535i, _545i, _550i, _6_series, _640i, _645i,
             _650i, _7_series, _740i, _745i, _750i, _760i, _840i,
             ACTHY3, ACTHY5, ALP_B6, ALP_B7, I3, I8, K1200, M2,
             M235I, M240I, M3, M4, M5, M550I, M6, X1, X3,
             X4, X5, X6, Z3, Z4]

# %%
df.head()
# Out:
#   auction_code  car_year   color make            model  body transmission  \
# 0          MAA      2013    BLUE  BMW        740LI XDR  4DSN            A
# 1          MAA      2017  SILVER  BMW  430I XDRIVE CPE  2DCP            A
# 2          MAA      2017    BLUE  BMW    X3 35I XDRIVE   SUV            A
# 3          MAA      2016  SILVER  BMW    X5 35I XDRIVE   SUV            A
# 4          MAA      2007    BLUE  BMW          X5 4.8L  4CUV            A
#
#    mileage  condition_grade  times_run  sale_price formatted_sold_date
# 0    47357               39          1       20900          2019-06-28
# 1    22870               45          1       26000          2019-06-28
# 2    39856               43          5       29250          2019-06-28
# 3    23606               44          8       35500          2019-06-28
# 4    65653               36          1        8700          2019-06-28

# %%
df.loc[df.model.str.contains(model.lower(), case = False), 'model']= model

# %%
for model in model_list:
    df.loc[df.model.str.contains(model.lower(), case = False), 'model']= model

# %%
df
# Out:
#       auction_code  car_year     color make      model  body transmission  \
# 0              MAA      2013      BLUE  BMW  740LI XDR  4DSN            A
# 1              MAA      2017    SILVER  BMW       430I  2DCP            A
# 2              MAA      2017      BLUE  BMW         X3   SUV            A
# 3              MAA      2016    SILVER  BMW         X5   SUV            A
# 4              MAA      2007      BLUE  BMW         X5  4CUV            A
# ...            ...       ...       ...  ...        ...   ...          ...
# 79693          MAA      2015  SPCEGREY  BMW       535I  4DSN            A
# 79694          MAA      2009      BLUE  BMW         X5  4CUV            A
# 79695          MAA      2017      GREY  BMW       430I  2DCV            A
# 79696          MAA      2016      GREY  BMW       528I  4DSN            A
# 79697          MAA      2016      BLUE  BMW       320I  4DSN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
df.to_csv('..\WHUPL\Output\BMW_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1> Audi <h1>

# %%
audi_df = pd.read_csv('..\WHUPL\Output\Audi.csv')
audi_df
# Out:
#       auction_code  car_year  color  make      model   subseries  body engine  \
# 0             KEYA      2010  WHITE  AUDI         Q5        3.2L  4SUV     6G
# 1             AREN      2016  WHITE  AUDI         A5     PREMIUM  2DCP    4GT
# 2             AREN      2014  BLACK  AUDI         Q7  SLINE PRST   SUV     6G
# 3             GOAA      2014  WHITE  AUDI     A4 FWD   PREMIUM +  4DSN    4GT
# 4             GOAA      2014  WHITE  AUDI         A7    3.0 PRES  4DHB     6G
# ...            ...       ...    ...   ...        ...         ...   ...    ...
# 50054         PXAA      2017  WHITE  AUDI     A4 AWD     PREMIUM  4DSN    4GT
# 50055         PXAA      2016  BLACK  AUDI     A4 FWD     PREMIUM  4DSN    4GT
# 50056         PXAA      2015  BROWN  AUDI         A5    PRESTIGE  2DCP    4GT
# 50057         PXAA      2015  BLACK  AUDI      Q5 4C   PREMIUM +   SUV    4ET
# 50058          MAA      2016  BLACK  AUDI  A6 AWD 4C   PREMIUM +  4DSN    4GT
#
# ...

# %%
audi_df = audi_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
audi_df
# Out:
#       auction_code  car_year  color  make      model  body transmission  \
# 0             KEYA      2010  WHITE  AUDI         Q5  4SUV            A
# 1             AREN      2016  WHITE  AUDI         A5  2DCP            A
# 2             AREN      2014  BLACK  AUDI         Q7   SUV            A
# 3             GOAA      2014  WHITE  AUDI     A4 FWD  4DSN            A
# 4             GOAA      2014  WHITE  AUDI         A7  4DHB            A
# ...            ...       ...    ...   ...        ...   ...          ...
# 50054         PXAA      2017  WHITE  AUDI     A4 AWD  4DSN            A
# 50055         PXAA      2016  BLACK  AUDI     A4 FWD  4DSN            A
# 50056         PXAA      2015  BROWN  AUDI         A5  2DCP            A
# 50057         PXAA      2015  BLACK  AUDI      Q5 4C   SUV            A
# 50058          MAA      2016  BLACK  AUDI  A6 AWD 4C  4DSN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
audi_models = audi_df.describe(include = 'all').loc['unique', :]
audi_m = []
for i in audi_df['model'].unique():
    audi_m.append(i)
    
audi_m.sort()
print(audi_m)
# Out:
# ['100', '90', 'A3', 'A3 1.4T E-TRON', 'A3 1.8T', 'A3 2.0T', 'A3 2.0T PREM', 'A3 2.0T QTRO', 'A3 AWD', 'A3 AWD 4C', 'A3 AWD 4C CNVRT', 'A3 AWD V6', 'A3 E-TRON', 'A3 FWD', 'A3 FWD 4C', 'A3 PRM', 'A3 TDI', 'A4', 'A4 - PREMIUM', 'A4 2.0T', 'A4 2.0T PREM', 'A4 2.0T QTRO', 'A4 4C', 'A4 ALLROAD', 'A4 AWD', 'A4 AWD 4C', 'A4 AWD PREMIUM', 'A4 AWD S LINE', 'A4 AWD V6', 'A4 FWD', 'A4 FWD 4C', 'A4 FWD V6', 'A4 KOMFORT +4DR', 'A4 SEDAN', 'A5', 'A5 2.0T PRES', 'A5 2.0T PRM', 'A5 2.0T QTRO', 'A5 3.0T QTRO', 'A5 AWD', 'A5 AWD 4C', 'A5 AWD CABRIO', 'A5 AWD V6', 'A5 CABRIO', 'A5 FWD', 'A5 FWD 4C', 'A6', 'A6 2.0T PRM', 'A6 2.0T QTRO', 'A6 3.0T PREM+', 'A6 3.0T QTRO', 'A6 AWD 4C', 'A6 AWD V6', 'A6 AWD V8', 'A6 FWD 4C', 'A6 FWD V6', 'A6 PRM+', 'A6 TDI QTRO', 'A6 V6', 'A7', 'A7 3.0 PREM+', 'A7 3.0T QTRO', 'A7 PRESTIGE', 'A7 TDI QTRO', 'A8', 'A8 AWD', 'A8 AWD V6', 'A8 AWD V8', 'A8 L', 'A8 L 4.0T QTRO', 'A8 L V12', 'A8 L V6', 'A8 L V8', 'A8 V6', 'A8 V8', 'A8L 3.0T PREM', 'ALLRD 2.0T QTRO', 'ALLROAD', 'CABRI
# ...

# %%
_100 = '100'
_90 = '90'
_A3 = 'A3'
_A4 = 'A4'
_A5 = 'A5'
_A6 = 'A6'
_A7 = 'A7'
_A8_v6 = 'A8 V6'
_A8_v8 = 'A8 V8'
_cabriolet = 'CABRIOLET'
_Q3 = 'Q3'
_Q5 = 'Q5'
_Q7 = 'Q7'
_R8 = 'R8'
_R8_V10 = 'R8 V10'
_R8_V8 = 'R8 V8'
_RS_5 = 'RS 5'
_RS_7 = 'RS 7'
_S3 = 'S3'
_S4 = 'S4'
_S5 = 'S5'
_S6 = 'S6'
_S7 = 'S7'
_S8 = 'S8'
_SQ5 = 'SQ5'
_TT = 'TT'
_TTS = 'TTS'
audi_model = _R8

# %%
audi_model_list = [_100,
_90,
_A3,
_A4,
_A5,
_A6,
_A7,
_A8_v6,
_A8_v8,
_cabriolet,
_Q3,
_Q5,
_Q7,
_R8,
_R8_V10,
_R8_V8,
_RS_5,
_RS_7,
_S3,
_S4,
_S5,
_S6,
_S7,
_S8,
_SQ5,
_TT,
_TTS]

# %%
audi_df.loc[audi_df.model.str.contains(audi_model.lower(), case = False), 'model']= audi_model

# %%
for audi_model in audi_model_list:
    audi_df.loc[audi_df.model.str.contains(audi_model.lower(), case = False), 'model']= audi_model

# %%
audi_df
# Out:
#       auction_code  car_year  color  make model  body transmission  mileage  \
# 0             KEYA      2010  WHITE  AUDI    Q5  4SUV            A    82069
# 1             AREN      2016  WHITE  AUDI    A5  2DCP            A     5192
# 2             AREN      2014  BLACK  AUDI    Q7   SUV            A    29864
# 3             GOAA      2014  WHITE  AUDI    A4  4DSN            A    56321
# 4             GOAA      2014  WHITE  AUDI    A7  4DHB            A    34370
# ...            ...       ...    ...   ...   ...   ...          ...      ...
# 50054         PXAA      2017  WHITE  AUDI    A4  4DSN            A    29290
# 50055         PXAA      2016  BLACK  AUDI    A4  4DSN            A    40438
# 50056         PXAA      2015  BROWN  AUDI    A5  2DCP            A    13253
# 50057         PXAA      2015  BLACK  AUDI    Q5   SUV            A    43508
# 50058          MAA      2016  BLACK  AUDI    A6  4DSN            A    36153
#
# ...

# %%
audi_df.to_csv('..\WHUPL\Output\Audi_models_clean.csv', index=False, header=True)

# %%
acura_df = pd.read_csv('..\WHUPL\Output\Acura.csv')
acura_df
# Out:
#       auction_code  car_year   color   make       model   subseries  body  \
# 0             AYCA      2005  SILVER  ACURA         MDX     TOURING   SUV
# 1             AYCA      2009  MAROON  ACURA         MDX    TECH PKG   SUV
# 2             AYCA      2001    GOLD  ACURA     MDX AWD     TOURING   SUV
# 3             GCAA      2014   WHITE  ACURA     RLX FWD    TECH PKG  4DSN
# 4              MAA      2014    GREY  ACURA     MDX AWD    TECH PKG   SUV
# ...            ...       ...     ...    ...         ...         ...   ...
# 27474          MAA      2016   BLACK  ACURA     MDX FWD      W/TECH   SUV
# 27475          MAA      2016   BLACK  ACURA     MDX AWD      W/TECH   SUV
# 27476          MAA      2016   WHITE  ACURA         ILX  TECH ASPEC  4DSN
# 27477         DALA      2015  SILVER  ACURA  TLX FWD V6     V6 TECH  4DSN
# 27478          MAA      2019   WHITE  ACURA  MDX AWD V6  TECH ASPEC   SUV
#
#       engine transmission  mileage  condition_grade  times_run   seller  \
# ...

# %%
acura_df = acura_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
acura_df
# Out:
#       auction_code  car_year   color   make       model  body transmission  \
# 0             AYCA      2005  SILVER  ACURA         MDX   SUV            A
# 1             AYCA      2009  MAROON  ACURA         MDX   SUV            A
# 2             AYCA      2001    GOLD  ACURA     MDX AWD   SUV            A
# 3             GCAA      2014   WHITE  ACURA     RLX FWD  4DSN            A
# 4              MAA      2014    GREY  ACURA     MDX AWD   SUV            A
# ...            ...       ...     ...    ...         ...   ...          ...
# 27474          MAA      2016   BLACK  ACURA     MDX FWD   SUV            A
# 27475          MAA      2016   BLACK  ACURA     MDX AWD   SUV            A
# 27476          MAA      2016   WHITE  ACURA         ILX  4DSN            A
# 27477         DALA      2015  SILVER  ACURA  TLX FWD V6  4DSN            A
# 27478          MAA      2019   WHITE  ACURA  MDX AWD V6   SUV            A
#
# ...

# %%
acura_models = acura_df.describe(include = 'all').loc['unique', :]
acura_m = []
for i in acura_df['model'].unique():
    acura_m.append(i)
    
acura_m.sort()
print(acura_m)
# Out:
# ['2.5', '2.5 TL', '3.2', 'CL', 'CL 4C', 'CL V6', 'CSX', 'CSX TECH PKG', 'EL', 'ILX', 'ILX HY', 'INTEGRA', 'LEGEND', 'MDX', 'MDX 4X4', 'MDX ADV ENT', 'MDX AWD', 'MDX AWD V6', 'MDX FWD', 'MDX FWD V6', 'MMD AWD V6', 'RDX', 'RDX AWD', 'RDX FWD', 'RL', 'RLX', 'RLX AWD', 'RLX AWD HYBRID', 'RLX FWD', 'RSX', 'SLX', 'TL', 'TL 5C', 'TL AWD V6', 'TL FWD V6', 'TL V6', 'TLX AWD V6', 'TLX FWD 4C', 'TLX FWD V6', 'TSX', 'TSX 4C', 'TSX FWD', 'TSX FWD 4C', 'TSX FWD V6', 'TSX SPT WGN', 'TSX SPT WGN 4C', 'VIGOR', 'ZDX']

# %%
_2_5 = '2.5'
_3_2 = '3.2'
_CL = 'CL'
_CSX = 'CSX'
_ILX = 'ILX'
_MDX = 'MDX'
_RDX = 'RDX'
_RLX = 'RLX'
_TL = 'TL'
_TLX = 'TLX'
_TSX = 'TSX'

acura_model = _RDX

# %%
acura_model_list = [_2_5,
_3_2,
_CL,
_CSX,
_ILX,
_MDX,
_RDX,
_RLX,
_TL,
_TLX,
_TSX]

# %%
acura_df.loc[acura_df.model.str.contains(acura_model.lower(), case = False), 'model']= acura_model

# %%
for acura_model in acura_model_list:
    acura_df.loc[acura_df.model.str.contains(acura_model.lower(), case = False), 'model']= acura_model

# %%
acura_df
# Out:
#       auction_code  car_year   color   make model  body transmission  mileage  \
# 0             AYCA      2005  SILVER  ACURA   MDX   SUV            A   182757
# 1             AYCA      2009  MAROON  ACURA   MDX   SUV            A   145063
# 2             AYCA      2001    GOLD  ACURA   MDX   SUV            A   205796
# 3             GCAA      2014   WHITE  ACURA   RLX  4DSN            A    41469
# 4              MAA      2014    GREY  ACURA   MDX   SUV            A    31563
# ...            ...       ...     ...    ...   ...   ...          ...      ...
# 27474          MAA      2016   BLACK  ACURA   MDX   SUV            A    62648
# 27475          MAA      2016   BLACK  ACURA   MDX   SUV            A    13261
# 27476          MAA      2016   WHITE  ACURA   ILX  4DSN            A    26116
# 27477         DALA      2015  SILVER  ACURA    TL  4DSN            A    69936
# 27478          MAA      2019   WHITE  ACURA   MDX   SUV            A     5738
#
# ...

# %%
acura_df.to_csv('..\WHUPL\Output\Acura_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Hyundai,title<h1>

# %%
hyundai_df = pd.read_csv('..\WHUPL\Output\Hyundai.csv')
hyundai_df
# Out:
#       auction_code  car_year   color     make            model subseries  \
# 0             NADE      2017     TAN  HYUNDAI          ELANTRA        SE
# 1             NASH      2016     RED  HYUNDAI          ELANTRA        SE
# 2             NASH      2017    GRAY  HYUNDAI          ELANTRA        SE
# 3             NASH      2017    GRAY  HYUNDAI          ELANTRA        SE
# 4             WPBA      2017   BLACK  HYUNDAI     SANTA FE FWD        SE
# ...            ...       ...     ...      ...              ...       ...
# 75928          MAA      2017    BLUE  HYUNDAI  SANTA SP AWD 4C      2.4L
# 75929          MAA      2016   BLACK  HYUNDAI           SONATA  2.4L LTD
# 75930          MAA      2017   WHITE  HYUNDAI  SANTA SP AWD 4C      2.4L
# 75931          MAA      2016   WHITE  HYUNDAI           ACCENT        SE
# 75932          MAA      2013  SILVER  HYUNDAI           SONATA   LIMITED
#
#        body engine transmission  mileage  condition_grade  times_run   seller  \
# ...

# %%
hyundai_df = hyundai_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
hyundai_df
# Out:
#       auction_code  car_year   color     make            model  body  \
# 0             NADE      2017     TAN  HYUNDAI          ELANTRA  4DSN
# 1             NASH      2016     RED  HYUNDAI          ELANTRA  4DSN
# 2             NASH      2017    GRAY  HYUNDAI          ELANTRA  4DSN
# 3             NASH      2017    GRAY  HYUNDAI          ELANTRA  4DSN
# 4             WPBA      2017   BLACK  HYUNDAI     SANTA FE FWD   SUV
# ...            ...       ...     ...      ...              ...   ...
# 75928          MAA      2017    BLUE  HYUNDAI  SANTA SP AWD 4C   SUV
# 75929          MAA      2016   BLACK  HYUNDAI           SONATA  4DSN
# 75930          MAA      2017   WHITE  HYUNDAI  SANTA SP AWD 4C   SUV
# 75931          MAA      2016   WHITE  HYUNDAI           ACCENT  4DSN
# 75932          MAA      2013  SILVER  HYUNDAI           SONATA  4DSN
#
#       transmission  mileage  condition_grade  times_run  sale_price  \
# 0                A    29780               42          1       11400
# ...

# %%
hyundai_models = hyundai_df.describe(include = 'all').loc['unique', :]
hyundai_m = []
for i in hyundai_df['model'].unique():
    hyundai_m.append(i)
    
hyundai_m.sort()
print(hyundai_m)
# Out:
# ['ACCENT', 'ACCENT GLS', 'ACCENT VALUE', 'AZERA', 'BRIO', 'ELAN SE', 'ELAN TRG', 'ELANTRA', 'ELANTRA - LI', 'ELANTRA GT', 'ELANTRA M/T', 'ELANTRA SEL', 'ENTOURAGE', 'EQUUS', 'GENESIS', 'GENESIS 4C', 'GENESIS 4X2', 'GENESIS 4X2 V6', 'GENESIS 4X2 V8', 'GENESIS AWD', 'GENESIS AWD V6', 'GENESIS COUP', 'GENESIS RWD V6', 'GENESIS V6', 'GENESIS V8', 'IONIQ', 'IONIQ ELECTRIC', 'IONIQ PLUG-IN', 'KONA AWD 4C', 'KONA FWD 4C', 'SANTA FE', 'SANTA FE 4C', 'SANTA FE 4X4 V6', 'SANTA FE AWD', 'SANTA FE AWD 4C', 'SANTA FE AWD V6', 'SANTA FE FWD', 'SANTA FE FWD 4C', 'SANTA FE FWD V6', 'SANTA FE LTD', 'SANTA FE ULT 4C', 'SANTA FE V6', 'SANTA FE XL', 'SANTA FE XL AWD', 'SANTA FE XL FWD', 'SANTA SP 4C', 'SANTA SP AWD', 'SANTA SP AWD 4C', 'SANTA SP FWD', 'SANTA SP FWD 4C', 'SANTE FE', 'SONATA', 'SONATA - LIM', 'SONATA 2.0', 'SONATA 2.0T', 'SONATA 4C', 'SONATA HY', 'SONATA HYBRID', 'SONATA LTD', 'SONATA SE', 'SONATA SEL', 'SONATA V6', 'TIBURON', 'TIBURON 4C', 'TIBURON V6', 'TUCSON', 'TUCSON - GLS', 'TUCSON 
# ...

# %%
_accent = 'ACCENT'
_elan = 'ELAN'
_elantra = 'ELANTRA'
_genesis = 'GENESIS'
_ioniq = 'IONIQ'
_kona = 'KONA'
_santa_fe = 'SANTA FE'
_santa_sp = 'SANTA SP'
_sonata = 'SONATA'
_tiburon = 'TIBURON'
_tucson = 'TUCSON'
_veloster = 'VELOSTER'
_veracruz = 'VERACRUZ'

hyundai_model = _accent

# %%
hyundai_model_list = [_accent,
_elan,
_elantra,
_genesis,
_ioniq,
_kona,
_santa_fe,
_santa_sp,
_sonata,
_tiburon,
_tucson,
_veloster,
_veracruz]

# %%
for hyundai_model in hyundai_model_list:
    hyundai_df.loc[hyundai_df.model.str.contains(hyundai_model.lower(), case = False), 'model']= hyundai_model

# %%
hyundai_df
# Out:
#       auction_code  car_year   color     make     model  body transmission  \
# 0             NADE      2017     TAN  HYUNDAI      ELAN  4DSN            A
# 1             NASH      2016     RED  HYUNDAI      ELAN  4DSN            A
# 2             NASH      2017    GRAY  HYUNDAI      ELAN  4DSN            A
# 3             NASH      2017    GRAY  HYUNDAI      ELAN  4DSN            A
# 4             WPBA      2017   BLACK  HYUNDAI  SANTA FE   SUV            A
# ...            ...       ...     ...      ...       ...   ...          ...
# 75928          MAA      2017    BLUE  HYUNDAI  SANTA SP   SUV            A
# 75929          MAA      2016   BLACK  HYUNDAI    SONATA  4DSN            A
# 75930          MAA      2017   WHITE  HYUNDAI  SANTA SP   SUV            A
# 75931          MAA      2016   WHITE  HYUNDAI    ACCENT  4DSN            A
# 75932          MAA      2013  SILVER  HYUNDAI    SONATA  4DSN            A
#
# ...

# %%
hyundai_df.to_csv('..\WHUPL\Output\Hyundai_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Honda<h1>

# %%
honda_df = pd.read_csv('..\WHUPL\Output\Honda.csv')
honda_df
# Out:
#       auction_code  car_year   color   make      model subseries  body engine  \
# 0             AYCA      1999   BLACK  HONDA  ACCORD V6        EX  2DCP     6G
# 1             AYCA      2009  SILVER  HONDA      CIVIC        EX  4DSN     4G
# 2             AYCA      2006  MAROON  HONDA   CR-V 4X4        EX   SUV     4G
# 3             KEYA      2007     RED  HONDA   CR-V 4X4      EX-L   SUV     4G
# 4              AAA      2010   BLACK  HONDA      CIVIC        EX  2DCP     4G
# ...            ...       ...     ...    ...        ...       ...   ...    ...
# 79917         FAAO      2018  SILVER  HONDA      CIVIC        LX  4DSN     4G
# 79918         SPAA      2009   WHITE  HONDA  ACCORD V6      EX-L  4DSN     6G
# 79919         NADE      2016  SILVER  HONDA    ODYSSEY      EX-L   VAN     6G
# 79920          MAA      2016    GREY  HONDA    ODYSSEY      EX-L   VAN     6G
# 79921         SSAA      2011    BLUE  HONDA  PILOT 4X4        LX  4SUV     6G
#
# ...

# %%
honda_df = honda_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
honda_df
# Out:
#       auction_code  car_year   color   make      model  body transmission  \
# 0             AYCA      1999   BLACK  HONDA  ACCORD V6  2DCP            A
# 1             AYCA      2009  SILVER  HONDA      CIVIC  4DSN            5
# 2             AYCA      2006  MAROON  HONDA   CR-V 4X4   SUV            A
# 3             KEYA      2007     RED  HONDA   CR-V 4X4   SUV            A
# 4              AAA      2010   BLACK  HONDA      CIVIC  2DCP            A
# ...            ...       ...     ...    ...        ...   ...          ...
# 79917         FAAO      2018  SILVER  HONDA      CIVIC  4DSN            A
# 79918         SPAA      2009   WHITE  HONDA  ACCORD V6  4DSN            A
# 79919         NADE      2016  SILVER  HONDA    ODYSSEY   VAN            A
# 79920          MAA      2016    GREY  HONDA    ODYSSEY   VAN            A
# 79921         SSAA      2011    BLUE  HONDA  PILOT 4X4  4SUV            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
honda_models = honda_df.describe(include = 'all').loc['unique', :]
honda_m = []
for i in honda_df['model'].unique():
    honda_m.append(i)
    
honda_m.sort()
print(honda_m)
# Out:
# ['650', 'ACCORD', 'ACCORD 4C', 'ACCORD 4C HY', 'ACCORD EX HY', 'ACCORD HY', 'ACCORD HY PLUG', 'ACCORD HY TRG', 'ACCORD HYBRID', 'ACCORD V6', 'ACRD X TOUR 4X4', 'ACRD X TOUR FWD', 'CBR1000', 'CBR250R', 'CBR300RAG (A', 'CBR500RD', 'CBR600RR', 'CBR600RRC', 'CBR650F ABS', 'CIVIC', 'CIVIC - EX', 'CIVIC DEL SOL', 'CIVIC DX', 'CIVIC FWD', 'CIVIC LX', 'CIVIC SI', 'CIVIC TYPE R', 'CLARITY PLUG-IN', 'CR-V', 'CR-V 4X4', 'CR-V AWD', 'CR-V AWD 4C', 'CR-V FWD', 'CR-V FWD 4C', 'CR-Z', 'CR-Z HY', 'CROSSTR 4C', 'CROSSTR 4X4 V6', 'CROSSTR FWD 4C', 'CROSSTR FWD V6', 'CRV', 'CTX130', 'CTX700E', 'ELEMENT 4X4', 'ELEMENT FWD', 'FIT', 'FIT SPT', 'GL18HPMC', 'GOLD WING', 'HONDA GL 1800', 'HR-V AWD', 'HR-V FWD', 'INSIGHT', 'INSIGHT HY', 'ODYSSEY', 'ODYSSEY TRG', 'PASSPORT 4X2', 'PASSPORT 4X2 V6', 'PASSPORT 4X4', 'PASSPORT 4X4 V6', 'PILOT', 'PILOT 4X4', 'PILOT AWD', 'PILOT FWD', 'PILOT HANDICAP', 'PRELUDE', 'RIDGELIN 4X4 CR', 'RIDGELIN AWD CR', 'RIDGELIN FWD CR', 'S2000', 'SHADOW SPIRIT', 'ST1300', 'VFR800A8 I
# ...

# %%
_650 = '650'
_accord = 'ACCORD'
_civic = 'CIVIC'
_cr_v = 'CR-V'
_crosstr = 'CROSSTR'
_element = 'ELEMENT'
_fit = 'FIT'
_hr_v = 'HR-V'
_odyssey = 'ODYSSEY'
_passport = 'PASSPORT'
_pilot = 'PILOT'
_ridgelin = 'RIDGELIN'


honda_model = _accord

# %%
honda_model_list = [_650,
_accord,
_civic,
_cr_v,
_crosstr,
_element,
_fit,
_hr_v,
_odyssey,
_passport,
_pilot,
_ridgelin]

# %%
for honda_model in honda_model_list:
    honda_df.loc[honda_df.model.str.contains(honda_model.lower(), case = False), 'model']= honda_model

# %%
honda_df
# Out:
#       auction_code  car_year   color   make    model  body transmission  \
# 0             AYCA      1999   BLACK  HONDA   ACCORD  2DCP            A
# 1             AYCA      2009  SILVER  HONDA    CIVIC  4DSN            5
# 2             AYCA      2006  MAROON  HONDA     CR-V   SUV            A
# 3             KEYA      2007     RED  HONDA     CR-V   SUV            A
# 4              AAA      2010   BLACK  HONDA    CIVIC  2DCP            A
# ...            ...       ...     ...    ...      ...   ...          ...
# 79917         FAAO      2018  SILVER  HONDA    CIVIC  4DSN            A
# 79918         SPAA      2009   WHITE  HONDA   ACCORD  4DSN            A
# 79919         NADE      2016  SILVER  HONDA  ODYSSEY   VAN            A
# 79920          MAA      2016    GREY  HONDA  ODYSSEY   VAN            A
# 79921         SSAA      2011    BLUE  HONDA    PILOT  4SUV            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
honda_df.to_csv('..\WHUPL\Output\Honda_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Land Rover<h1>

# %%
land_rover_df = pd.read_csv('..\WHUPL\Output\Land_Rover.csv')
land_rover_df
# Out:
#       auction_code  car_year   color       make           model   subseries  \
# 0              MAA      2012    BLUE  LANDROVER         LR4 LUX         LUX
# 1             NADE      2012  SILVER  LANDROVER          RR HSE         HSE
# 2             FAAO      2014   WHITE  LANDROVER  RANGE R SPT V6          SE
# 3             FAAO      2006  SILVER  LANDROVER     RANGE ROVER         HSE
# 4             FAAO      2007  SILVER  LANDROVER     RANGE ROVER         HSE
# ...            ...       ...     ...        ...             ...         ...
# 45284          MAA      2018   BLACK  LANDROVER  RANGE R EVOQUE  SE PREMIUM
# 45285         FAAO      2016    GRAY  LANDROVER  RANGE ROVER V6         HSE
# 45286         THAA      2016    GRAY  LANDROVER  RANGE R SPT V6       V6 SE
# 45287         FAAO      2019   WHITE  LANDROVER  RANGE ROVER V6         HSE
# 45288          MAA      2013   BLACK  LANDROVER     RANGE R SPT         HSE
#
# ...

# %%
land_rover_df = land_rover_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
land_rover_df
# Out:
#       auction_code  car_year   color       make           model  body  \
# 0              MAA      2012    BLUE  LANDROVER         LR4 LUX  4SUV
# 1             NADE      2012  SILVER  LANDROVER          RR HSE  4SUV
# 2             FAAO      2014   WHITE  LANDROVER  RANGE R SPT V6   SUV
# 3             FAAO      2006  SILVER  LANDROVER     RANGE ROVER  4SUV
# 4             FAAO      2007  SILVER  LANDROVER     RANGE ROVER  4CUV
# ...            ...       ...     ...        ...             ...   ...
# 45284          MAA      2018   BLACK  LANDROVER  RANGE R EVOQUE  5DHB
# 45285         FAAO      2016    GRAY  LANDROVER  RANGE ROVER V6   SUV
# 45286         THAA      2016    GRAY  LANDROVER  RANGE R SPT V6   SUV
# 45287         FAAO      2019   WHITE  LANDROVER  RANGE ROVER V6   SUV
# 45288          MAA      2013   BLACK  LANDROVER     RANGE R SPT   SUV
#
#       transmission  mileage  condition_grade  times_run  sale_price  \
# ...

# %%
land_rover_models = land_rover_df.describe(include = 'all').loc['unique', :]
land_rover_m = []
for i in land_rover_df['model'].unique():
    land_rover_m.append(i)
    
land_rover_m.sort()
print(land_rover_m)
# Out:
# ['3.5L V8', 'DEFENDER', 'DISCOVERY', 'DISCOVERY LE', 'DISCOVERY LSE', 'DISCOVERY SD', 'DISCOVERY SE', 'DISCOVERY SE7', 'DISCOVERY SPORT', 'FREELANDER', 'FREELANDER AWD', 'LR2', 'LR2 HSE', 'LR2 HSE LUX', 'LR2 HSE TEC', 'LR3', 'LR3 BASE 5', 'LR3 BASE 7', 'LR3 HSE7', 'LR3 HSE7 LUX', 'LR3 V6', 'LR3 V8', 'LR4', 'LR4 4X4', 'LR4 BASE 5', 'LR4 BASE 7', 'LR4 HSE', 'LR4 HSE MET LE', 'LR4 HSE5', 'LR4 HSE5 PLU', 'LR4 HSE7', 'LR4 HSE7 LUX', 'LR4 HSE7 PLU', 'LR4 LUX', 'LR4 LUX LE', 'PREMIUM', 'R/R S/C LWB V8', 'RAN SPT HSE', 'RANG R VELAR 4C', 'RANG R VELAR V6', 'RANGE R EVOQUE', 'RANGE R SPT', 'RANGE R SPT V6', 'RANGE R SPT V8', 'RANGE ROVER', 'RANGE ROVER LWB', 'RANGE ROVER S/C', 'RANGE ROVER SE', 'RANGE ROVER SPO', 'RANGE ROVER V6', 'RANGE ROVER V8', 'RANGER EVOQUE', 'RR ATB', 'RR EVOQUE', 'RR HSE', 'RR HSE LUX', 'RR S/C', 'RR SC', 'RR SC ATB', 'RRE DYN PREM 3', 'RRE DYN PREM 5', 'RRE PRES PRM', 'RRE PURE PLU 3', 'RRE PURE PLU 5', 'RRE PURE PRM 3', 'RRE PURE PRM 5', 'RRS ATB', 'RRS GT', 'RRS HS
# ...

# %%
_freelander = 'FREELANDER'
_lr2 = 'LR2'
_lr3 = 'LR3'
_lr4 = 'LR4'
_evoque = 'EVOQUE'
_hse = 'HSE'



land_rover_model = _lr2

# %%
land_rover_model_list = [_freelander,
_lr2,
_lr3,
_lr4,
_evoque,
_hse]

# %%
for land_rover_model in land_rover_model_list:
    land_rover_df.loc[land_rover_df.model.str.contains(land_rover_model.lower(), case = False), 'model']= land_rover_model

# %%
land_rover_df
# Out:
#       auction_code  car_year   color       make           model  body  \
# 0              MAA      2012    BLUE  LANDROVER             LR4  4SUV
# 1             NADE      2012  SILVER  LANDROVER             HSE  4SUV
# 2             FAAO      2014   WHITE  LANDROVER  RANGE R SPT V6   SUV
# 3             FAAO      2006  SILVER  LANDROVER     RANGE ROVER  4SUV
# 4             FAAO      2007  SILVER  LANDROVER     RANGE ROVER  4CUV
# ...            ...       ...     ...        ...             ...   ...
# 45284          MAA      2018   BLACK  LANDROVER          EVOQUE  5DHB
# 45285         FAAO      2016    GRAY  LANDROVER  RANGE ROVER V6   SUV
# 45286         THAA      2016    GRAY  LANDROVER  RANGE R SPT V6   SUV
# 45287         FAAO      2019   WHITE  LANDROVER  RANGE ROVER V6   SUV
# 45288          MAA      2013   BLACK  LANDROVER     RANGE R SPT   SUV
#
#       transmission  mileage  condition_grade  times_run  sale_price  \
# ...

# %%
land_rover_df.to_csv('..\WHUPL\Output\Land_Rover_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>KIA<h1>

# %%
kia_df = pd.read_csv('..\WHUPL\Output\KIA.csv')
kia_df
# Out:
#       auction_code  car_year   color make           model subseries  body  \
# 0             NVAA      2018    BLUE  KIA           FORTE         S  4DSN
# 1             NVAA      2017  PURPLE  KIA          OPTIMA        LX  4DSN
# 2             NVAA      2015  SILVER  KIA            K900   PREMIUM  4DSN
# 3             NVAA      2015   BLACK  KIA          OPTIMA        LX  4DSN
# 4             NVAA      2017    GRAY  KIA  SORENTO AWD 4C        LX   SUV
# ...            ...       ...     ...  ...             ...       ...   ...
# 71254         WLNC      2013     RED  KIA             RIO        LX  4DSN
# 71255         WLNC      2016   WHITE  KIA  SORENTO AWD V6        LX   SUV
# 71256         NVAA      2017   WHITE  KIA            SOUL      BASE  5WGN
# 71257         NVAA      2016   BLACK  KIA           FORTE        LX  4DSN
# 71258         NVAA      2014    GRAY  KIA            SOUL      BASE  4WGN
#
#       engine transmission  mileage  condition_grade  times_run   seller  \
# ...

# %%
kia_df = kia_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
kia_df
# Out:
#       auction_code  car_year   color make           model  body transmission  \
# 0             NVAA      2018    BLUE  KIA           FORTE  4DSN            A
# 1             NVAA      2017  PURPLE  KIA          OPTIMA  4DSN            A
# 2             NVAA      2015  SILVER  KIA            K900  4DSN            A
# 3             NVAA      2015   BLACK  KIA          OPTIMA  4DSN            A
# 4             NVAA      2017    GRAY  KIA  SORENTO AWD 4C   SUV            A
# ...            ...       ...     ...  ...             ...   ...          ...
# 71254         WLNC      2013     RED  KIA             RIO  4DSN            A
# 71255         WLNC      2016   WHITE  KIA  SORENTO AWD V6   SUV            A
# 71256         NVAA      2017   WHITE  KIA            SOUL  5WGN            A
# 71257         NVAA      2016   BLACK  KIA           FORTE  4DSN            A
# 71258         NVAA      2014    GRAY  KIA            SOUL  4WGN            A
#
# ...

# %%
kia_models = kia_df.describe(include = 'all').loc['unique', :]
kia_m = []
for i in kia_df['model'].unique():
    kia_m.append(i)
    
kia_m.sort()
print(kia_m)
# Out:
# ['AMANTI', 'BORREGO 4X2 V6', 'BORREGO 4X2 V8', 'BORREGO 4X4 V6', 'BORREGO 4X4 V8', 'BORREGO V6', 'CADENZA', 'FORT', 'FORTE', 'FORTE - EX L', 'FORTE 5', 'FORTE EX AT', 'FORTE LX +', 'FORTE LX+MT', 'FORTE5', 'K900', 'K900 V6', 'K900 V8', 'NIRO', 'NIRO PLUG-IN', 'OPTIMA', 'OPTIMA 4C', 'OPTIMA SX LTD', 'OPTIMA V6', 'QUINTO', 'RIO', 'RIO 5', 'RIO LX', 'RIO LX + MT', 'RONDO', 'RONDO 4C', 'RONDO FWD 4C', 'RONDO FWD V6', 'RONDO V6', 'SADONA', 'SEDO', 'SEDONA', 'SEDONA LX', 'SEDONA LX PREM', 'SEDONA LX+ PREM', 'SEDONA LX+PREM', 'SEDONA PREM', 'SEPHIA', 'SOREN LX+ TURBO', 'SORENTO', 'SORENTO - SX', 'SORENTO 4C', 'SORENTO 4X2', 'SORENTO 4X2 V6', 'SORENTO 4X4', 'SORENTO 4X4 V6', 'SORENTO AWD', 'SORENTO AWD 4C', 'SORENTO AWD V6', 'SORENTO FWD', 'SORENTO FWD 4C', 'SORENTO FWD V6', 'SORENTO LX AWD', 'SORENTO V6', 'SOUL', 'SOUL EV', 'SOUL EX', 'SOUL EX+', 'SPECTRA', 'SPECTRA5', 'SPORTAGE', 'SPORTAGE     4C', 'SPORTAGE 4X2', 'SPORTAGE 4X2 4C', 'SPORTAGE 4X2 V6', 'SPORTAGE 4X4', 'SPORTAGE 4X4 4C', 'SP
# ...

# %%
_forte = 'FORTE'
_niro = 'NIRO'
_optima = 'OPTIMA'
_rondo = 'RONDO'
_rio = 'RIO'
_sedona = 'SEDONA'
_sorento = 'SORENTO'
_soul = 'SOUL'
_spectra = 'SPECTRA'
_sportage = 'SPORTAGE'
_stinger = 'STINGER'



kia_model = _forte

# %%
kia_model_list = [_forte,
_niro,
_optima,
_rondo,
_rio,
_sedona,
_sorento,
_soul,
_spectra,
_sportage,
_stinger]

# %%
for kia_model in kia_model_list:
    kia_df.loc[kia_df.model.str.contains(kia_model.lower(), case = False), 'model']= kia_model

# %%
kia_df
# Out:
#       auction_code  car_year   color make    model  body transmission  \
# 0             NVAA      2018    BLUE  KIA    FORTE  4DSN            A
# 1             NVAA      2017  PURPLE  KIA   OPTIMA  4DSN            A
# 2             NVAA      2015  SILVER  KIA     K900  4DSN            A
# 3             NVAA      2015   BLACK  KIA   OPTIMA  4DSN            A
# 4             NVAA      2017    GRAY  KIA  SORENTO   SUV            A
# ...            ...       ...     ...  ...      ...   ...          ...
# 71254         WLNC      2013     RED  KIA      RIO  4DSN            A
# 71255         WLNC      2016   WHITE  KIA  SORENTO   SUV            A
# 71256         NVAA      2017   WHITE  KIA     SOUL  5WGN            A
# 71257         NVAA      2016   BLACK  KIA    FORTE  4DSN            A
# 71258         NVAA      2014    GRAY  KIA     SOUL  4WGN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
kia_df.to_csv('..\WHUPL\Output\KIA_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Lexus<h1>

# %%
lexus_df = pd.read_csv('..\WHUPL\Output\Lexus.csv')
lexus_df
# Out:
#       auction_code  car_year  color   make       model subseries  body engine  \
# 0              AAA      2014  BLACK  LEXUS  GS 350 4X2   F SPORT  4DSN     6G
# 1             BCAA      2015  WHITE  LEXUS     CT 200H    HYBRID  4DSN     4H
# 2             BCAA      2014    TAN  LEXUS     ES 300H    HYBRID  4DSN     4H
# 3             FAAO      2016   GRAY  LEXUS  RC 350 4X2   F SPORT  2DCP     6G
# 4             FAAO      2014  WHITE  LEXUS  IS 350 4X2   F SPORT  4DSN     6G
# ...            ...       ...    ...    ...         ...       ...   ...    ...
# 13016          MAA      2019  WHITE  LEXUS          GX  460 PREM   SUV     8G
# 13017          MAA      2017  BLACK  LEXUS      RX AWD    RX 350   SUV     6G
# 13018          MAA      2017  WHITE  LEXUS      RX AWD    RX 350   SUV     6G
# 13019          MAA      2016  WHITE  LEXUS  RC 350 AWD   F SPORT  2DCP     6G
# 13020          MAA      2016   GREY  LEXUS     ES 300H    HYBRID  4DSN     4H
#
# ...

# %%
lexus_df = lexus_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
lexus_df
# Out:
#       auction_code  car_year  color   make       model  body transmission  \
# 0              AAA      2014  BLACK  LEXUS  GS 350 4X2  4DSN            A
# 1             BCAA      2015  WHITE  LEXUS     CT 200H  4DSN            A
# 2             BCAA      2014    TAN  LEXUS     ES 300H  4DSN            A
# 3             FAAO      2016   GRAY  LEXUS  RC 350 4X2  2DCP            A
# 4             FAAO      2014  WHITE  LEXUS  IS 350 4X2  4DSN            A
# ...            ...       ...    ...    ...         ...   ...          ...
# 13016          MAA      2019  WHITE  LEXUS          GX   SUV            A
# 13017          MAA      2017  BLACK  LEXUS      RX AWD   SUV            A
# 13018          MAA      2017  WHITE  LEXUS      RX AWD   SUV            A
# 13019          MAA      2016  WHITE  LEXUS  RC 350 AWD  2DCP            A
# 13020          MAA      2016   GREY  LEXUS     ES 300H  4DSN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
lexus_models = lexus_df.describe(include = 'all').loc['unique', :]
lexus_m = []
for i in lexus_df['model'].unique():
    lexus_m.append(i)
    
lexus_m.sort()
print(lexus_m)
# Out:
# ['CT', 'CT 200', 'CT 200H', 'CT 200H F SPORT', 'CT 200H F SPT', 'CT 200H FSPORT', 'CT 200H HY', 'CT F SPORT', 'ES 300', 'ES 300H', 'ES 300H HY', 'ES 330', 'ES 350', 'ES 350 TRG', 'ES 4C', 'ES V6', 'ES300', 'GS 200T', 'GS 300', 'GS 300 AWD', 'GS 350', 'GS 350 4X2', 'GS 350 4X2 F SP', 'GS 350 4X2 FSPT', 'GS 350 AWD', 'GS 350 AWD F SP', 'GS 350 AWD FSPT', 'GS 430', 'GS 450H', 'GS 4X2 4C', 'GS 4X2 V6', 'GS AWD V6', 'GS F', 'GX', 'GX 460', 'GX 460 4X4', 'GX 460 AWD', 'GX 460 PREMIUM', 'GX 470', 'HS 250H', 'IS 200T', 'IS 200T    F SP', 'IS 200T F SPORT', 'IS 250', 'IS 250 4X2', 'IS 250 4X2 F SP', 'IS 250 4X2 FSPT', 'IS 250 AWD', 'IS 250 AWD F SP', 'IS 250 AWD FSPT', 'IS 250 FSPORT', 'IS 250C', 'IS 300', 'IS 300     F SP', 'IS 300    F SP', 'IS 300  F SP', 'IS 300 AWD', 'IS 300 F SPORT', 'IS 300 FSPORT', 'IS 350', 'IS 350 4X2', 'IS 350 4X2 FSPT', 'IS 350 AWD', 'IS 350 AWD F SP', 'IS 350 AWD FSPT', 'IS 350 F SPT', 'IS 350 F-SPT', 'IS 350C', 'IS 4X2 4C', 'IS 4X2 V6', 'IS AWD V6', 'IS F', 'IS 
# ...

# %%
_ct = 'CT'
_es_350 = 'ES 350'
_gs_350 = 'GS 350'
_gx_460 = 'GX 460'
_is_200 = 'IS 200'
_is_250 = 'IS 250'
_is_300 = 'IS 300'
_is_350 = 'IS 350'
_ls_460 = 'LS 460'
_ls_4x2 = 'LS 4X2'
_lx_570 = 'LX 570'
_lx_470 = 'LX 470'
_ls_awd = 'LS AWD'
_rc_200t = 'RC200 T'
_rc_359 = 'RC 350'
_rx_350 = 'RX 350'
_rx_450h = 'RX 450H'
_rx_awd = 'RX AWD'




lexus_model = _ct

# %%
lexus_model_list = [_ct,
_es_350,
_gs_350,
_gx_460,
_is_200,
_is_250,
_is_300,
_is_350,
_ls_460,
_ls_4x2,
_lx_570,
_lx_470,
_ls_awd,
_rc_200t,
_rc_359,
_rx_350,
_rx_450h,
_rx_awd]

# %%
for lexus_model in lexus_model_list:
    lexus_df.loc[lexus_df.model.str.contains(lexus_model.lower(), case = False), 'model']= lexus_model

# %%
lexus_df
# Out:
#       auction_code  car_year  color   make    model  body transmission  \
# 0              AAA      2014  BLACK  LEXUS   GS 350  4DSN            A
# 1             BCAA      2015  WHITE  LEXUS       CT  4DSN            A
# 2             BCAA      2014    TAN  LEXUS  ES 300H  4DSN            A
# 3             FAAO      2016   GRAY  LEXUS   RC 350  2DCP            A
# 4             FAAO      2014  WHITE  LEXUS   IS 350  4DSN            A
# ...            ...       ...    ...    ...      ...   ...          ...
# 13016          MAA      2019  WHITE  LEXUS       GX   SUV            A
# 13017          MAA      2017  BLACK  LEXUS   RX AWD   SUV            A
# 13018          MAA      2017  WHITE  LEXUS   RX AWD   SUV            A
# 13019          MAA      2016  WHITE  LEXUS   RC 350  2DCP            A
# 13020          MAA      2016   GREY  LEXUS  ES 300H  4DSN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
lexus_df.to_csv('..\WHUPL\Output\Lexus_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Lincoln<h1>

# %%
lincoln_df = pd.read_csv('..\WHUPL\Output\Lincoln.csv')
lincoln_df
# Out:
#       auction_code  car_year    color     make          model  subseries  \
# 0             AYCA      2006    BLACK  LINCOLN  NAVIGATOR 4X2   ULTIMATE
# 1             AYCA      2006      TAN  LINCOLN  NAVIGATOR 4X2   ULTIMATE
# 2             AYCA      2005     GRAY  LINCOLN       TOWN CAR  SIGNATURE
# 3             AYCA      2002    WHITE  LINCOLN          LS V8      SPORT
# 4             SLAA      2009  FR SILK  LINCOLN       TOWN CAR    SIG LTD
# ...            ...       ...      ...      ...            ...        ...
# 23996          MAA      2017     BLUE  LINCOLN     MKC AWD 4C    RESERVE
# 23997          MAA      2017    WHITE  LINCOLN     MKZ AWD 4C    RESERVE
# 23998          MAA      2018      RED  LINCOLN     MKZ AWD 4C    RESERVE
# 23999          MAA      2017      RED  LINCOLN     MKC AWD 4C     SELECT
# 24000          MAA      2017      RED  LINCOLN     MKC AWD 4C     SELECT
#
#        body engine transmission   mileage  condition_grade  times_run  \
# ...

# %%
lincoln_df = lincoln_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
lincoln_df
# Out:
#       auction_code  car_year    color     make          model  body  \
# 0             AYCA      2006    BLACK  LINCOLN  NAVIGATOR 4X2   SUV
# 1             AYCA      2006      TAN  LINCOLN  NAVIGATOR 4X2   SUV
# 2             AYCA      2005     GRAY  LINCOLN       TOWN CAR  4DSN
# 3             AYCA      2002    WHITE  LINCOLN          LS V8  4DSN
# 4             SLAA      2009  FR SILK  LINCOLN       TOWN CAR  4DSN
# ...            ...       ...      ...      ...            ...   ...
# 23996          MAA      2017     BLUE  LINCOLN     MKC AWD 4C   SUV
# 23997          MAA      2017    WHITE  LINCOLN     MKZ AWD 4C  4DSN
# 23998          MAA      2018      RED  LINCOLN     MKZ AWD 4C  4DSN
# 23999          MAA      2017      RED  LINCOLN     MKC AWD 4C   SUV
# 24000          MAA      2017      RED  LINCOLN     MKC AWD 4C   SUV
#
#       transmission   mileage  condition_grade  times_run  sale_price  \
# 0                A  121736.0               23        1.0      4800.0
# ...

# %%
lincoln_models = lincoln_df.describe(include = 'all').loc['unique', :]
lincoln_m = []
for i in lincoln_df['model'].unique():
    lincoln_m.append(i)
    
lincoln_m.sort()
print(lincoln_m)
# Out:
# ['2KT AWD V6', 'AVIATOR 4X2', 'AVIATOR AWD', 'BLACKWD 4X2 CR', 'CAPRI', 'CONTINENTAL', 'CONTINENTAL AWD', 'CONTINENTAL FWD', 'LS', 'LS V6', 'LS V8', 'MARK VIII', 'MKC AWD 4C', 'MKC FWD 4C', 'MKS AWD', 'MKS AWD V', 'MKS AWD V6', 'MKS FWD', 'MKS FWD V6', 'MKT', 'MKT AWD V6', 'MKT FWD 4C', 'MKT FWD V6', 'MKX', 'MKX AWD', 'MKX AWD SUV', 'MKX FWD', 'MKX FWD SUV', 'MKZ AWD', 'MKZ AWD 4C', 'MKZ AWD V6', 'MKZ FWD', 'MKZ FWD 4C', 'MKZ FWD V6', 'NAUTILUS AWD 4C', 'NAUTILUS AWD V6', 'NAUTILUS FWD 4C', 'NAUTILUS FWD V6', 'NAVIGATOR 4X2', 'NAVIGATOR 4X4', 'NAVIGATOR L 4X2', 'NAVIGATOR L 4X4', 'TOWN CAR', 'TOWN CAR LIMO', 'TOWN CAR SIG']

# %%
_continental = 'CONTINENTAL'
_mkc_awd = 'MKC AWD'
_mkc_fwd = 'MKC FWD'
_mks_awd = 'MKS AWD'
_mks_fwd = 'MKS FWD'
_mkt_awd = 'MKT AWD'
_mkt_fwd = 'MKT FWD'
_mkx_awd = 'MKX AWD'
_mkx_fwd = 'MKX FWD'
_mkz_awd = 'MKZ AWD'
_mkz_fwd = 'MKZ FWD'
_nautilus_fwd = 'NAUTILUS FWD'
_nautilus_awd = 'NAUTILUS AWD'
_navigator = 'NAVIGATOR'
_town_car = 'TOWN CAR'




lincoln_model = _continental

# %%
lincoln_model_list = [_continental,
_mkc_awd,
_mkc_fwd,
_mks_awd,
_mks_fwd,
_mkt_awd,
_mkt_fwd,
_mkx_awd,
_mkx_fwd,
_mkz_awd,
_mkz_fwd,
_nautilus_fwd,
_nautilus_awd,
_navigator,
_town_car]

# %%
for lincoln_model in lincoln_model_list:
    lincoln_df.loc[lincoln_df.model.str.contains(lincoln_model.lower(), case = False), 'model']= lincoln_model

# %%
lincoln_df
# Out:
#       auction_code  car_year    color     make      model  body transmission  \
# 0             AYCA      2006    BLACK  LINCOLN  NAVIGATOR   SUV            A
# 1             AYCA      2006      TAN  LINCOLN  NAVIGATOR   SUV            A
# 2             AYCA      2005     GRAY  LINCOLN   TOWN CAR  4DSN            A
# 3             AYCA      2002    WHITE  LINCOLN      LS V8  4DSN            A
# 4             SLAA      2009  FR SILK  LINCOLN   TOWN CAR  4DSN            A
# ...            ...       ...      ...      ...        ...   ...          ...
# 23996          MAA      2017     BLUE  LINCOLN    MKC AWD   SUV            A
# 23997          MAA      2017    WHITE  LINCOLN    MKZ AWD  4DSN            A
# 23998          MAA      2018      RED  LINCOLN    MKZ AWD  4DSN            A
# 23999          MAA      2017      RED  LINCOLN    MKC AWD   SUV            A
# 24000          MAA      2017      RED  LINCOLN    MKC AWD   SUV            A
#
# ...

# %%
lincoln_df.to_csv('..\WHUPL\Output\Lincoln_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Maserati<h1>

# %%
maserati_df = pd.read_csv('..\WHUPL\Output\Maserati.csv')
maserati_df
# Out:
#      auction_code  car_year   color      make         model   subseries  body  \
# 0            AYCA      2004    BLUE  MASERATI         COUPE  CAMBIOCORS  2DCP
# 1            LMAA      2007  MAROON  MASERATI  QUATTROPORTE    SPORT GT  4DSN
# 2             RAA      2015    BLUE  MASERATI    GHIBLI AWD        S Q4  4DSN
# 3             RAA      2015     RED  MASERATI    GHIBLI AWD        S Q4  4DSN
# 4            BCAA      2011  MAROON  MASERATI   GRANTURISMO           S  2DCP
# ...           ...       ...     ...       ...           ...         ...   ...
# 9859          MAA      2014  SILVER  MASERATI    GHIBLI AWD        S Q4  4DSN
# 9860          MAA      2014   BLACK  MASERATI    GHIBLI AWD        S Q4  4DSN
# 9861          MAA      2014   BLACK  MASERATI    GHIBLI AWD        S Q4  4DSN
# 9862          MAA      2008   BLACK  MASERATI  QUATTROPORTE  SPORT GT S  4DSN
# 9863          RAA      2014    BLUE  MASERATI    GHIBLI AWD        S Q4  4DSN
#
# ...

# %%
maserati_df = maserati_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
maserati_df
# Out:
#      auction_code  car_year   color      make         model  body  \
# 0            AYCA      2004    BLUE  MASERATI         COUPE  2DCP
# 1            LMAA      2007  MAROON  MASERATI  QUATTROPORTE  4DSN
# 2             RAA      2015    BLUE  MASERATI    GHIBLI AWD  4DSN
# 3             RAA      2015     RED  MASERATI    GHIBLI AWD  4DSN
# 4            BCAA      2011  MAROON  MASERATI   GRANTURISMO  2DCP
# ...           ...       ...     ...       ...           ...   ...
# 9859          MAA      2014  SILVER  MASERATI    GHIBLI AWD  4DSN
# 9860          MAA      2014   BLACK  MASERATI    GHIBLI AWD  4DSN
# 9861          MAA      2014   BLACK  MASERATI    GHIBLI AWD  4DSN
# 9862          MAA      2008   BLACK  MASERATI  QUATTROPORTE  4DSN
# 9863          RAA      2014    BLUE  MASERATI    GHIBLI AWD  4DSN
#
#      transmission  mileage  condition_grade  times_run  sale_price  \
# 0               A    42583               27          1       14000
# ...

# %%
maserati_models = maserati_df.describe(include = 'all').loc['unique', :]
maserati_m = []
for i in maserati_df['model'].unique():
    maserati_m.append(i)
    
maserati_m.sort()
print(maserati_m)
# Out:
# ['BITURBO', 'COUPE', 'GHIBLI', 'GHIBLI 4X2', 'GHIBLI AWD', 'GRANSPORT', 'GRANTURISMO', 'LEVANTE', 'QUATTROP', 'QUATTROP 4X2 V6', 'QUATTROP 4X2 V8', 'QUATTROP AWD V6', 'QUATTROPORTE', 'SPYDER']

# %%
_ghibli = 'GHIBLI'
_quattrop = 'QUATTROP'





maserati_model = _ghibli

# %%
maserati_model_list = [_ghibli,
_quattrop]

# %%
for maserati_model in maserati_model_list:
    maserati_df.loc[maserati_df.model.str.contains(maserati_model.lower(), case = False), 'model']= maserati_model

# %%
maserati_df
# Out:
#      auction_code  car_year   color      make        model  body transmission  \
# 0            AYCA      2004    BLUE  MASERATI        COUPE  2DCP            A
# 1            LMAA      2007  MAROON  MASERATI     QUATTROP  4DSN            A
# 2             RAA      2015    BLUE  MASERATI       GHIBLI  4DSN            A
# 3             RAA      2015     RED  MASERATI       GHIBLI  4DSN            A
# 4            BCAA      2011  MAROON  MASERATI  GRANTURISMO  2DCP            A
# ...           ...       ...     ...       ...          ...   ...          ...
# 9859          MAA      2014  SILVER  MASERATI       GHIBLI  4DSN            A
# 9860          MAA      2014   BLACK  MASERATI       GHIBLI  4DSN            A
# 9861          MAA      2014   BLACK  MASERATI       GHIBLI  4DSN            A
# 9862          MAA      2008   BLACK  MASERATI     QUATTROP  4DSN            A
# 9863          RAA      2014    BLUE  MASERATI       GHIBLI  4DSN            A
#
# ...

# %%
maserati_df.to_csv('..\WHUPL\Output\Maserati_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Mercedes<h1>

# %%
mercedes_df = pd.read_csv('..\WHUPL\Output\Mercedes.csv')
mercedes_df
# Out:
#       auction_code  car_year   color      make     model   subseries  body  \
# 0             AYCA      2006   WHITE  MERCEDES     E350W        3.5L  4DSN
# 1              MAA      2011    BLUE  MERCEDES   ML350W4       ML350   SUV
# 2             DALA      2010   BLACK  MERCEDES     C300W  C300 SPORT  4DSN
# 3             BIGH      2005  SILVER  MERCEDES  SL55 AMG    5.5L AMG  2DCV
# 4             FAAO      2011   WHITE  MERCEDES     GL450       GL450   SUV
# ...            ...       ...     ...       ...       ...         ...   ...
# 45486          MAA      2014   BLACK  MERCEDES    S550V4        S550  4DSN
# 45487         FAAO      2015   BLACK  MERCEDES     C300W        C300  4DSN
# 45488          AAA      2019    BLUE  MERCEDES    C300W4       C 300  4DSN
# 45489          AAA      2013   BLACK  MERCEDES     GL450       GL450   SUV
# 45490         DALA      2018   BLACK  MERCEDES  GLE350W4     GLE 350   SUV
#
# ...

# %%
mercedes_df = mercedes_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
mercedes_df
# Out:
#       auction_code  car_year   color      make     model  body transmission  \
# 0             AYCA      2006   WHITE  MERCEDES     E350W  4DSN            A
# 1              MAA      2011    BLUE  MERCEDES   ML350W4   SUV            A
# 2             DALA      2010   BLACK  MERCEDES     C300W  4DSN            A
# 3             BIGH      2005  SILVER  MERCEDES  SL55 AMG  2DCV            A
# 4             FAAO      2011   WHITE  MERCEDES     GL450   SUV            A
# ...            ...       ...     ...       ...       ...   ...          ...
# 45486          MAA      2014   BLACK  MERCEDES    S550V4  4DSN            A
# 45487         FAAO      2015   BLACK  MERCEDES     C300W  4DSN            A
# 45488          AAA      2019    BLUE  MERCEDES    C300W4  4DSN            A
# 45489          AAA      2013   BLACK  MERCEDES     GL450   SUV            A
# 45490         DALA      2018   BLACK  MERCEDES  GLE350W4   SUV            A
#
# ...

# %%
mercedes_models = mercedes_df.describe(include = 'all').loc['unique', :]
mercedes_m = []
for i in mercedes_df['model'].unique():
    mercedes_m.append(i)
    
mercedes_m.sort()
print(mercedes_m)
# Out:
# ['190E', '190E 2.6', '2500 SPRINTE', '300SE', '3500', '4 MATIC', '560 SERIES', 'AMG GT', 'AMG SL63', 'AMG SL65', 'AMG SLC43', 'B-CLASS', 'B200', 'B250', 'B250E', 'B250W4', 'BENZ 450SL C', 'C230K', 'C230ML', 'C230W', 'C230W4', 'C230WZ', 'C230WZMT', 'C240S', 'C240S4', 'C240W', 'C240W4', 'C250', 'C250C', 'C250W', 'C250W4', 'C280W4', 'C300', 'C300 4MATIC', 'C300A', 'C300A4', 'C300C', 'C300C4', 'C300W', 'C300W4', 'C300W4  4MATIC', 'C300W4  LUXURY', 'C300W4 4MATIC', 'C32 AMG', 'C320C', 'C320S', 'C320S4', 'C320W', 'C320WZ', 'C320WZ4', 'C350', 'C350C', 'C350C4', 'C350W', 'C350W4', 'C350WE', 'C400W4', 'C43A4 AMG', 'C43C4 AMG', 'C43W4 AMG', 'C450W4 AMG', 'C55 AMG', 'C63 AMG', 'C63 S AMG', 'C63A AMG', 'C63AS AMG', 'C63C AMG', 'C63CS AMG', 'C63W AMG', 'C63WS AMG', 'CL500C', 'CL55 AMG', 'CL550C', 'CL550C4', 'CL600C', 'CL63 AMG', 'CL65 AMG', 'CLA250C', 'CLA250C4', 'CLA45 AMG', 'CLA45 AMG4', 'CLK320A', 'CLK320C', 'CLK350A', 'CLK500A', 'CLK500C', 'CLK55 AMG', 'CLK63A AMG', 'CLS 450C', 'CLS400C', 'CL
# ...

# %%
_190e = '190E'
_c230 = 'C230'
_c250 = 'C250'
_c320 = 'C320'
_c350 = 'C350'
_c300 = 'C300'
_c320 = 'C320'
_c63 = 'C63'
_cla250c = 'CLA250C'
_cla45_amg = 'CLA45 AMG'
_ck550 = 'CK550C'
_c350 = 'C350'
_c63 = 'C63'
_cla250c = 'CLA250C'
_cls550c = 'CLS550C'
_cls63 = 'CLS63'
_e250 = 'E250'
_e280w = 'E280W'
_e400 = 'E400'
_e500w = 'E500W'
_e55 = 'E55'
_g55 = 'G55'
_e63 = 'E63'
_g500 = 'G500'
_gl320 = 'GL320'
_g63 = 'G63'
_gl350 = 'GL350'
_gle350 = 'GLE350W'
_gl450 = 'GL450'
_gle63sc4 = 'GLE63SC4'
_gle63w4 = 'GLE63W4'
_metris = 'METRIS'
_ml350 = 'ML350'
_ml400 = 'ML400'
_ml550 = 'ML550'
_r350 = 'R350'
_s550 = 'S550'
_sls = 'SLS'
_2500 = '2500'
_3500 = '3500'



mercedes_model = _c230

# %%
mercedes_model_list = [_190e,
_c230,
_c250,
_c320,
_c350,
_c300,
_c320,
_c63,
_cla250c,
_cla45_amg,
_ck550,
_c350,
_c63,
_cla250c,
_cls550c,
_cls63,
_e250,
_e280w,
_e400,
_e500w,
_e55,
_g55,
_e63,
_g500,
_gl320,
_g63,
_gl350,
_gle350,
_gl450,
_gle63sc4,
_gle63w4,
_metris,
_ml350,
_ml400,
_ml550,
_r350,
_s550,
_sls,
_2500,
_3500]

# %%
for mercedes_model in mercedes_model_list:
    mercedes_df.loc[mercedes_df.model.str.contains(mercedes_model.lower(), case = False), 'model']= mercedes_model

# %%
mercedes_df
# Out:
#       auction_code  car_year   color      make     model  body transmission  \
# 0             AYCA      2006   WHITE  MERCEDES     E350W  4DSN            A
# 1              MAA      2011    BLUE  MERCEDES     ML350   SUV            A
# 2             DALA      2010   BLACK  MERCEDES      C300  4DSN            A
# 3             BIGH      2005  SILVER  MERCEDES  SL55 AMG  2DCV            A
# 4             FAAO      2011   WHITE  MERCEDES     GL450   SUV            A
# ...            ...       ...     ...       ...       ...   ...          ...
# 45486          MAA      2014   BLACK  MERCEDES      S550  4DSN            A
# 45487         FAAO      2015   BLACK  MERCEDES      C300  4DSN            A
# 45488          AAA      2019    BLUE  MERCEDES      C300  4DSN            A
# 45489          AAA      2013   BLACK  MERCEDES     GL450   SUV            A
# 45490         DALA      2018   BLACK  MERCEDES   GLE350W   SUV            A
#
# ...

# %%
mercedes_df.to_csv('..\WHUPL\Output\Mercedes_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Porsche<h1>

# %%
porsche_df = pd.read_csv('..\WHUPL\Output\Porsche.csv')
porsche_df
# Out:
#       auction_code  car_year   color     make            model  subseries  \
# 0             AYCA      2002     RED  PORSCHE          911 CAB  CARRERA 4
# 1             AAAI      2004    BLUE  PORSCHE       CAYENNE V8          S
# 2              RAA      2016   WHITE  PORSCHE  PANAMERA AWD V6   AWD EDIT
# 3             AREN      2013   BLACK  PORSCHE       CAYENNE V8      TURBO
# 4             HATA      2001  SILVER  PORSCHE          911 CAB  CARRERA 4
# ...            ...       ...     ...      ...              ...        ...
# 23150          MAA      2010   BLACK  PORSCHE     PANAMERA AWD      TURBO
# 23151          MAA      2013   BLACK  PORSCHE  PANAMERA AWD V6          4
# 23152          RAA      2010   BLACK  PORSCHE     PANAMERA AWD      TURBO
# 23153         FAAO      2012   WHITE  PORSCHE       CAYENNE V8          S
# 23154          MAA      2017   WHITE  PORSCHE       CAYENNE V6   PLATINUM
#
#        body engine transmission   mileage  condition_grade  times_run  \
# ...

# %%
porsche_df = porsche_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
porsche_df
# Out:
#       auction_code  car_year   color     make            model  body  \
# 0             AYCA      2002     RED  PORSCHE          911 CAB  2DCV
# 1             AAAI      2004    BLUE  PORSCHE       CAYENNE V8   SUV
# 2              RAA      2016   WHITE  PORSCHE  PANAMERA AWD V6  4DHB
# 3             AREN      2013   BLACK  PORSCHE       CAYENNE V8   SUV
# 4             HATA      2001  SILVER  PORSCHE          911 CAB  2DCV
# ...            ...       ...     ...      ...              ...   ...
# 23150          MAA      2010   BLACK  PORSCHE     PANAMERA AWD  4DHB
# 23151          MAA      2013   BLACK  PORSCHE  PANAMERA AWD V6  4DHB
# 23152          RAA      2010   BLACK  PORSCHE     PANAMERA AWD  4DHB
# 23153         FAAO      2012   WHITE  PORSCHE       CAYENNE V8   SUV
# 23154          MAA      2017   WHITE  PORSCHE       CAYENNE V6   SUV
#
#       transmission   mileage  condition_grade  times_run  sale_price  \
# ...

# %%
porsche_models = mercedes_df.describe(include = 'all').loc['unique', :]
porsche_m = []
for i in porsche_df['model'].unique():
    porsche_m.append(i)
    
porsche_m.sort()
print(porsche_m)
# Out:
# ['718 BOX S', '718 BOXS GTS', '718 BOXS S', '718 BOXST S', '718 BOXSTER', '718 BOXSTER S', '718 BOXSTR S', '718 CAY GTS', '718 CAYMAN', '718 CAYMAN S', '718BOXSTER S', '911', '911  6C', '911 2WD 6C', '911 4 GTS', '911 4X2', '911 4X2 6C', '911 6C', '911 AWD', '911 AWD 6C', '911 AWD 6G', '911 C-4 CPE', '911 CAB', '911 CABRIOLET', '911 CABRLT S', '911 CAR CAB', '911 CAR GTS', '911 CARERA 4S', '911 CARERA4S', '911 CARERRA', '911 CARR', '911 CARR 4S', '911 CARR CAB', '911 CARR GTS', '911 CARR S', '911 CARR S CABR', '911 CARRARA', '911 CARRERA', '911 CARRERA 4', '911 CARRERA 4S', '911 CARRERA 4X2', '911 CARRERA AWD', '911 CARRERA CAB', '911 CARRERA GTS', '911 CARRERA S', '911 CARRERA4', '911 COUPE', '911 CPE', '911 CPE S', '911 GT2', '911 GT3', '911 S TURBO', '911 SC', '911 TAR 4GTS', '911 TARGA', '911 TARGA 4', '911 TARGA 4S', '911 TUR CAB', '911 TURBO', '911 TURBO S', '911CAR 4SCAB', '911CAR CAB', '911CAR GTS C', '911CAR S CAB', '911CAR4 SCAB', '911CAR4S CAB', '911CARR 4GTS', '911CARR CA
# ...

# %%
_718 = '718'
_718_cayman = '718 CAYMAN'
_911 = '911'
_911_gt2 = '911 GT2'
_911_gt3 = '911 GT3'
_911_turbo = '911 TURBO'
_cayenne = 'CAYENNE'
_cayman = 'CAYMAN'
_macan = 'MACAN'
_panamera = 'PANAMERA'







porsche_model = _911

# %%
porsche_model_list = [_718,
_718_cayman,
_911,
_911_gt2,
_911_gt3,
_911_turbo,
_cayenne,
_cayman,
_macan,
_panamera]

# %%
for porsche_model in porsche_model_list:
    porsche_df.loc[porsche_df.model.str.contains(porsche_model.lower(), case = False), 'model']= porsche_model

# %%
porsche_df
# Out:
#       auction_code  car_year   color     make     model  body transmission  \
# 0             AYCA      2002     RED  PORSCHE       911  2DCV            A
# 1             AAAI      2004    BLUE  PORSCHE   CAYENNE   SUV            A
# 2              RAA      2016   WHITE  PORSCHE  PANAMERA  4DHB            A
# 3             AREN      2013   BLACK  PORSCHE   CAYENNE   SUV            A
# 4             HATA      2001  SILVER  PORSCHE       911  2DCV            6
# ...            ...       ...     ...      ...       ...   ...          ...
# 23150          MAA      2010   BLACK  PORSCHE  PANAMERA  4DHB            A
# 23151          MAA      2013   BLACK  PORSCHE  PANAMERA  4DHB            A
# 23152          RAA      2010   BLACK  PORSCHE  PANAMERA  4DHB            A
# 23153         FAAO      2012   WHITE  PORSCHE   CAYENNE   SUV            A
# 23154          MAA      2017   WHITE  PORSCHE   CAYENNE   SUV            A
#
# ...

# %%
porsche_df.to_csv('..\WHUPL\Output\Porsche_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Toyota<h1>

# %%
toyota_df = pd.read_csv('..\WHUPL\Output\Toyota.csv')
toyota_df
# Out:
#       auction_code  car_year   color    make            model subseries  body  \
# 0             KEYA      2001  SILVER  TOYOTA      SEQUOIA 4X4   LIMITED   SUV
# 1             AYCA      2009  SILVER  TOYOTA  HIGHLNDR 4X4 V6   LIMITED   SUV
# 2              AAA      2016   BLACK  TOYOTA          COROLLA        LE  4DSN
# 3              AAA      2016   BLACK  TOYOTA         CAMRY 4C        SE  4DSN
# 4              AAA      2015   BLACK  TOYOTA          COROLLA    S PLUS  4DSN
# ...            ...       ...     ...     ...              ...       ...   ...
# 65546         MMAA      2017   BLKSD  TOYOTA         RAV4 AWD       XLE   SUV
# 65547         NASH      2016    GRAY  TOYOTA         RAV4 FWD       XLE   SUV
# 65548         SVAA      2012   WHITE  TOYOTA          COROLLA         L  4DSN
# 65549          MAA      2015   WHITE  TOYOTA  HIGHLNDR AWD V6   LIMITED   SUV
# 65550          MAA      2016   WHITE  TOYOTA       SIENNA FWD       XLE   VAN
#
# ...

# %%
toyota_df = toyota_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
toyota_df
# Out:
#       auction_code  car_year   color    make            model  body  \
# 0             KEYA      2001  SILVER  TOYOTA      SEQUOIA 4X4   SUV
# 1             AYCA      2009  SILVER  TOYOTA  HIGHLNDR 4X4 V6   SUV
# 2              AAA      2016   BLACK  TOYOTA          COROLLA  4DSN
# 3              AAA      2016   BLACK  TOYOTA         CAMRY 4C  4DSN
# 4              AAA      2015   BLACK  TOYOTA          COROLLA  4DSN
# ...            ...       ...     ...     ...              ...   ...
# 65546         MMAA      2017   BLKSD  TOYOTA         RAV4 AWD   SUV
# 65547         NASH      2016    GRAY  TOYOTA         RAV4 FWD   SUV
# 65548         SVAA      2012   WHITE  TOYOTA          COROLLA  4DSN
# 65549          MAA      2015   WHITE  TOYOTA  HIGHLNDR AWD V6   SUV
# 65550          MAA      2016   WHITE  TOYOTA       SIENNA FWD   VAN
#
#       transmission  mileage  condition_grade  times_run  sale_price  \
# 0                O   206970               23          3        1900
# ...

# %%
toyota_models = toyota_df.describe(include = 'all').loc['unique', :]
toyota_m = []
for i in toyota_df['model'].unique():
    toyota_m.append(i)
    
toyota_m.sort()
print(toyota_m)
# Out:
# ['4 RUNNER', '4 RUNNER 4X4', '4-RUNNER', '4RUNNER 4X2', '4RUNNER 4X2 V6', '4RUNNER 4X2 V8', '4RUNNER 4X4', '4RUNNER 4X4 V6', '4RUNNER 4X4 V8', '86', 'AVALON', 'AVALON 4C', 'AVALON V6', 'C-HR', 'CAMRY', 'CAMRY 4C', 'CAMRY LE', 'CAMRY SE', 'CAMRY SOLARA 4C', 'CAMRY SOLARA V6', 'CAMRY V6', 'CAMRY XLE', 'CELICA', 'CELICA FWD', 'COROLLA', 'CRESSIDA', 'ECHO', 'FJ CRUISER 4X4', 'HIGHLANDER', 'HIGHLNDR', 'HIGHLNDR 4X4', 'HIGHLNDR 4X4 V6', 'HIGHLNDR AWD V6', 'HIGHLNDR FWD', 'HIGHLNDR FWD 4C', 'HIGHLNDR FWD V6', 'HIGHLNDR LTD HY', 'MATRIX', 'MATRIX 4C', 'MATRIX AWD', 'MATRIX AWD 4C', 'MATRIX FWD', 'MATRIX FWD 4C', 'PICKUP 4X2', 'PICKUP 4X4', 'PREVIA', 'PREVIA ALL-TRAC', 'PRIUS', 'PRIUS C', 'PRIUS PLUG IN', 'PRIUS PLUG-IN', 'PRIUS PRIME', 'PRIUS V', 'PRIUS V HYBRID', 'RAV 4', 'RAV4', 'RAV4 4C', 'RAV4 4X4 4C', 'RAV4 4X4 V6', 'RAV4 AWD', 'RAV4 EV', 'RAV4 FWD', 'RAV4 FWD 4C', 'RAV4 FWD V6', 'SEQUOIA 4X2', 'SEQUOIA 4X2 V8', 'SEQUOIA 4X4', 'SEQUOIA 4X4 V8', 'SHORT BED', 'SIENNA', 'SIENNA AWD', 'SIEN
# ...

# %%
_4_runner = 'RUNNER'
_avalon = 'AVALON'
_camry = 'CAMRY'
_celica = 'CELICA'
_highlander = 'HIGHL'
_matrix = 'MATRIX'
_prius = 'PRIUS'
_rav4 = 'RAV'
_sequoia = 'SEQUOIA'
_sienna = 'SIENNA'
_solara = 'SOLARA'
_tacoma = 'TACOMA'
_tundra = 'TUNDRA'
_venza = 'VENZA'



toyota_model = _avalon

# %%
toyota_model_list = [_4_runner,
_avalon,
_camry,
_celica,
_highlander,
_matrix,
_prius,
_rav4,
_sequoia,
_sienna,
_solara,
_tacoma,
_tundra,
_venza]

# %%
for toyota_model in toyota_model_list:
    toyota_df.loc[toyota_df.model.str.contains(toyota_model.lower(), case = False), 'model']= toyota_model

# %%
toyota_df
# Out:
#       auction_code  car_year   color    make    model  body transmission  \
# 0             KEYA      2001  SILVER  TOYOTA  SEQUOIA   SUV            O
# 1             AYCA      2009  SILVER  TOYOTA    HIGHL   SUV            A
# 2              AAA      2016   BLACK  TOYOTA  COROLLA  4DSN            A
# 3              AAA      2016   BLACK  TOYOTA    CAMRY  4DSN            A
# 4              AAA      2015   BLACK  TOYOTA  COROLLA  4DSN            A
# ...            ...       ...     ...     ...      ...   ...          ...
# 65546         MMAA      2017   BLKSD  TOYOTA      RAV   SUV            A
# 65547         NASH      2016    GRAY  TOYOTA      RAV   SUV            A
# 65548         SVAA      2012   WHITE  TOYOTA  COROLLA  4DSN            A
# 65549          MAA      2015   WHITE  TOYOTA    HIGHL   SUV            A
# 65550          MAA      2016   WHITE  TOYOTA   SIENNA   VAN            A
#
#        mileage  condition_grade  times_run  sale_price formatted_sold_date
# ...

# %%
toyota_df.to_csv('..\WHUPL\Output\Toyota_models_clean.csv', index=False, header=True)

# %% [markdown]
# <h1>Volkswagon<h1>

# %%
volkswagon_df = pd.read_csv('..\WHUPL\Output\Volkswagon.csv')
volkswagon_df
# Out:
#       auction_code  car_year   color        make       model   subseries  \
# 0             AYCA      2009   BLACK  VOLKSWAGEN  TIGUAN AWD         SEL
# 1             AYCA      2009  SILVER  VOLKSWAGEN      ROUTAN          SE
# 2             AYCA      2014     TAN  VOLKSWAGEN    JETTA 4C          SE
# 3             NADE      2012   BLACK  VOLKSWAGEN  TIGUAN FWD          LE
# 4             GOAA      2016   WHITE  VOLKSWAGEN   PASSAT 4C      1.8T S
# ...            ...       ...     ...         ...         ...         ...
# 61239          MAA      2017     RED  VOLKSWAGEN        GOLF   WOLFSBURG
# 61240          MAA      2015   WHITE  VOLKSWAGEN       JETTA     GLI SEL
# 61241          MAA      2017   BLACK  VOLKSWAGEN   PASSAT 4C  RLINE COMF
# 61242          MAA      2017    GREY  VOLKSWAGEN       JETTA      1.4T S
# 61243         SLAA      2011    BLUE  VOLKSWAGEN    JETTA 5C          SE
#
#        body engine transmission   mileage  condition_grade  times_run  \
# ...

# %%
volkswagon_df = volkswagon_df.drop(columns=['subseries', 'engine', 'seller'], axis = 1)
volkswagon_df
# Out:
#       auction_code  car_year   color        make       model  body  \
# 0             AYCA      2009   BLACK  VOLKSWAGEN  TIGUAN AWD   SUV
# 1             AYCA      2009  SILVER  VOLKSWAGEN      ROUTAN   VAN
# 2             AYCA      2014     TAN  VOLKSWAGEN    JETTA 4C  4DSN
# 3             NADE      2012   BLACK  VOLKSWAGEN  TIGUAN FWD   SUV
# 4             GOAA      2016   WHITE  VOLKSWAGEN   PASSAT 4C  4DSN
# ...            ...       ...     ...         ...         ...   ...
# 61239          MAA      2017     RED  VOLKSWAGEN        GOLF  4DHB
# 61240          MAA      2015   WHITE  VOLKSWAGEN       JETTA  4DSN
# 61241          MAA      2017   BLACK  VOLKSWAGEN   PASSAT 4C  4DSN
# 61242          MAA      2017    GREY  VOLKSWAGEN       JETTA  4DSN
# 61243         SLAA      2011    BLUE  VOLKSWAGEN    JETTA 5C  4DSN
#
#       transmission   mileage  condition_grade  times_run  sale_price  \
# 0                A   96696.0               34        1.0      7100.0
# ...

# %%
volkswagon_models = volkswagon_df.describe(include = 'all').loc['unique', :]
volkswagon_m = []
for i in volkswagon_df['model'].unique():
    volkswagon_m.append(i)
    
volkswagon_m.sort()
print(volkswagon_m)
# Out:
# ['4C', 'ATLAS AWD V6', 'ATLAS FWD 4C', 'ATLAS FWD V6', 'BEET TREND', 'BEETLE', 'BEETLE 4C', 'BEETLE 5C', 'CABRIO', 'CC', 'CC 2.0T SE F', 'CC 4X4 V6', 'CC AWD V6', 'CC FWD 4C', 'CC FWD V6', 'CC SPT +', 'E-GOLF', 'EOS', 'EOS 4C', 'EOS V6', 'EUROVAN', 'EUROVAN CAMPER', 'GLI', 'GOLF', 'GOLF 4C', 'GOLF 5C', 'GOLF ALLTRACK', 'GOLF AWD', 'GOLF CITY', 'GOLF FWD', 'GOLF GLS', 'GOLF GTI', 'GOLF R', 'GOLF SPTWGN AWD', 'GOLF SPTWGN FWD', 'GTI', 'GTI 4C', 'GTI V6', 'JETTA', 'JETTA 2.5L SE', 'JETTA 4C', 'JETTA 5C', 'JETTA CITY', 'JETTA SEDAN', 'JETTA TSI', 'JETTA V6', 'PASSAT', 'PASSAT 1.8T', 'PASSAT 4C', 'PASSAT 5C', 'PASSAT AWD', 'PASSAT AWD 4C', 'PASSAT AWD V6', 'PASSAT AWD V8', 'PASSAT FWD', 'PASSAT FWD 4C', 'PASSAT FWD V6', 'PASSAT V6', 'PHAETON V12', 'PHAETON V8', 'RABBIT', 'ROUTAN', 'SCIROCCO', 'TIGUAN', 'TIGUAN 2.0T S', 'TIGUAN 2.0T SEL', 'TIGUAN 4X4', 'TIGUAN AWD', 'TIGUAN FWD', 'TIGUAN LTD AWD', 'TIGUAN LTD FWD', 'TIGUAN S', 'TIGUAN SE', 'TOUAREG', 'TOUAREG 2 V6', 'TOUAREG 4X4 V6', 'TOUA
# ...

# %%
_atlas = 'ATLAS'
_beetle = 'BEETLE'
_cc = 'CC'
_eos = 'EOS'
_golf = 'GOLF'
_gti = 'GTI'
_jetta = 'JETTA'
_passat = 'PASSAT'
_tiguan = 'TIGUAN'
_toureg = 'TOUAREG'






volkswagon_model = _atlas

# %%
volkswagon_model_list = [_atlas,
_beetle,
_cc,
_eos,
_golf,
_gti,
_jetta,
_passat,
_tiguan,
_toureg]

# %%
for volkswagon_model in volkswagon_model_list:
    volkswagon_df.loc[volkswagon_df.model.str.contains(volkswagon_model.lower(), case = False), 'model']= volkswagon_model

# %%
volkswagon_df
# Out:
#       auction_code  car_year   color        make   model  body transmission  \
# 0             AYCA      2009   BLACK  VOLKSWAGEN  TIGUAN   SUV            A
# 1             AYCA      2009  SILVER  VOLKSWAGEN  ROUTAN   VAN            A
# 2             AYCA      2014     TAN  VOLKSWAGEN   JETTA  4DSN            A
# 3             NADE      2012   BLACK  VOLKSWAGEN  TIGUAN   SUV            A
# 4             GOAA      2016   WHITE  VOLKSWAGEN  PASSAT  4DSN            A
# ...            ...       ...     ...         ...     ...   ...          ...
# 61239          MAA      2017     RED  VOLKSWAGEN    GOLF  4DHB            A
# 61240          MAA      2015   WHITE  VOLKSWAGEN   JETTA  4DSN            A
# 61241          MAA      2017   BLACK  VOLKSWAGEN  PASSAT  4DSN            A
# 61242          MAA      2017    GREY  VOLKSWAGEN   JETTA  4DSN            A
# 61243         SLAA      2011    BLUE  VOLKSWAGEN   JETTA  4DSN            A
#
# ...

# %%
volkswagon_df.to_csv('..\WHUPL\Output\Volkswagon_models_clean.csv', index=False, header=True)
